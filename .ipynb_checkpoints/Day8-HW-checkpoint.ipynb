# %% [markdown]
# ## Introduction to Data Science
#
# #### University of Redlands - DATA 101
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website: data101.joannabieri.com](https://joannabieri.com/data101.html)
#
# ---------------------------------------
# # Homework Day 8
# ---------------------------------------
#
# GOALS:
#
# 1. Load data into Python that you find online
# 2. Understand data types and fix some errors
# 3. Find your own data to play with
#
# ----------------------------------------------------------
#
# This homework has **5 questions** and **1 problem**.
#
# NOTE: Be kind to yourself. Working with data can be hard! Every data set is different. **Seriously** come get help! Come to lab!

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %% [markdown]
# ## Try reading in some data - csv
#
# Go to the [Cal Fire Website](https://www.fire.ca.gov/incidents) and scroll to the bottom to see the Incident Data. We will download the file named **ALL DATA AS CSV** this should put the data file into your Downloads folder.
#
# Next you need to move the file **mapdataall.csv** from your Downloads folder into your Day8 folder where you are doing your homework. You can open your Downloads folder and drag the file into JupyterLab side bar. Then I can run the command
#
#     DF_raw = pd.read_csv('mapdataall.csv')
#
# to load the data and look at the data frame.

# %% [markdown]
# **Q1** How many variables and observations?
#
# **Q2** How many different incident types are there?
#
# **Q3** Make a histogram of the acres burned and color the bars by whether or not the incident was a calfire incident. You will probably need to make a mask to remove very small and very large fires. How many fires burned more than 100,000 acres? What is the largest fire in the data?
#
# **Extra Q** EXTRA - CHALLENGE - See if you can create a graph that answers the question: Are fires getting bigger or more frequent over time? You get complete creative control on how to answer this question!

# %%
DF_raw = pd.read_csv('mapdataall.csv')
DF_raw
# Out:
#       incident_name incident_is_final  incident_date_last_update  \
# 0       Bridge Fire                 Y       2018-01-09T13:46:00Z
# 1         Pala Fire                 Y       2020-09-16T14:07:35Z
# 2        River Fire                 Y       2022-10-24T11:39:23Z
# 3     Fawnskin Fire                 Y       2013-04-22T09:00:00Z
# 4         Gold Fire                 Y       2013-05-01T07:00:00Z
# ...             ...               ...                        ...
# 2742  Verjeles Fire                 Y       2024-10-07T21:48:53Z
# 2743      Wood Fire                 N       2024-10-08T21:57:58Z
# 2744   Posta 3 Fire                 N  2024-10-08T18:20:51-07:00
# 2745  Cemetery Fire                 N       2024-10-08T15:28:24Z
# 2746    Piney Fire                  N  2024-10-08T19:04:50-07:00
#
#      incident_date_created          incident_administrative_unit  \
# 0     2017-10-31T11:22:00Z       Shasta-Trinity National Forest
# 1     2009-05-24T14:56:00Z               CAL FIRE San Diego Unit
# 2     2013-02-24T08:16:00Z          CAL FIRE San Bernardino Unit
# 3     2013-04-20T17:30:00Z        San Bernardino National Forest
# 4     2013-04-30T12:59:00Z  CAL FIRE Madera-Mariposa-Merced Unit
# ...                    ...                                   ...
# 2742  2024-10-06T16:45:33Z      CAL FIRE Nevada-Yuba-Placer Unit
# 2743  2024-10-06T19:57:47Z      CAL FIRE Humboldt-Del Norte Unit
# 2744  2024-10-07T15:01:33Z               CAL FIRE San Diego Unit
# 2745  2024-10-08T12:18:12Z            CAL FIRE Lassen-Modoc Unit
# 2746  2024-10-08T16:09:00Z     CAL FIRE San Benito-Monterey Unit
#
#       incident_administrative_unit_url incident_county  \
# 0                                  NaN          Shasta
# 1                                  NaN       San Diego
# 2                                  NaN            Inyo
# 3                                  NaN  San Bernardino
# 4                                  NaN          Madera
# ...                                ...             ...
# 2742                               NaN            Yuba
# 2743                               NaN        Humboldt
# 2744                               NaN       San Diego
# 2745                               NaN           Modoc
# 2746                               NaN        Monterey
#
#                                       incident_location  \
# 0     I-5 and Turntable Bay, 7 miles NE of Shasta Lake
# 1           Hwy 76 and Pala Temecula, northwest of Pala
# 2     south of Narrow Gauge Rd & north of Hwy 136, e...
# 3     west of Delamar Mountain, north of the communi...
# 4     Between Road 210 and Road 200 near Fine Gold C...
# ...                                                 ...
# 2742               Los Verjeles Road and Loma Rica Road
# 2743  Wood Ranch Road and Redwood Drive, southwest o...
# 2744            Old Highway 80 and La Posta Road, Campo
# 2745                     100 block County Road 89, Adin
# 2746   Hastings Reservation Road/Martin Road, Jamesburg
#
#       incident_acres_burned  incident_containment  ... incident_latitude  \
# 0                      37.0                 100.0  ...         40.774000
# 1                     122.0                 100.0  ...          1.000000
# 2                     407.0                 100.0  ...         36.602575
# 3                      30.0                 100.0  ...         34.288877
# 4                     274.0                 100.0  ...         37.116295
# ...                     ...                   ...  ...               ...
# 2742                   12.0                 100.0  ...         39.357400
# 2743                   26.0                  80.0  ...         40.176118
# 2744                  413.0                 100.0  ...         32.723782
# 2745                   56.0                   NaN  ...         41.194920
# 2746                  180.0                   0.0  ...         36.378918
#
#      incident_type                           incident_id  \
# 0              NaN  2ca11d45-8139-4c16-8af0-880d99b21e82
# 1         Wildfire  8f61f461-552d-4538-b186-35ab030da416
# 2              NaN  094719ba-a47b-4abb-9ec5-a506b2b9fd23
# 3              NaN  58f89ff8-bd3e-4355-b1c0-8fa05c747d3f
# 4              NaN  357ffc13-bef9-48eb-810f-c5de851972eb
# ...            ...                                   ...
# 2742      Wildfire  1b69ebdd-1add-4f85-a9f9-47275bc5118e
# 2743      Wildfire  100b8102-e9f6-411f-9440-26b92b8ebe94
# 2744      Wildfire  f75ae145-52cc-4e4e-ae7e-37007a29eca1
# 2745      Wildfire  684041c4-6817-400c-96f5-22fedfdaf059
# 2746      Wildfire  958b27e4-3413-461d-b2f8-0a866707c9f0
#
#                                            incident_url  \
# 0     https://www.fire.ca.gov/incidents/2017/10/31/b...
# 1     https://www.fire.ca.gov/incidents/2009/5/24/pa...
# 2     https://www.fire.ca.gov/incidents/2013/2/24/ri...
# 3     https://www.fire.ca.gov/incidents/2013/4/20/fa...
# 4     https://www.fire.ca.gov/incidents/2013/4/30/go...
# ...                                                 ...
# 2742  https://www.fire.ca.gov/incidents/2024/10/6/ve...
# 2743  https://www.fire.ca.gov/incidents/2024/10/6/wo...
# 2744  https://www.fire.ca.gov/incidents/2024/10/7/po...
# 2745  https://www.fire.ca.gov/incidents/2024/10/8/ce...
# 2746  https://www.fire.ca.gov/incidents/2024/10/8/pi...
#
#      incident_date_extinguished incident_dateonly_extinguished  \
# 0          2018-01-09T13:46:00Z                     2018-01-09
# 1          2009-05-25T00:00:00Z                     2009-05-25
# 2          2013-02-28T20:00:00Z                     2013-02-28
# 3          2013-04-22T09:00:00Z                     2013-04-22
# 4          2013-05-01T07:00:00Z                     2013-05-01
# ...                         ...                            ...
# 2742       2024-10-07T08:04:00Z                     2024-10-07
# 2743                        NaN                            NaN
# 2744                        NaN                            NaN
# 2745                        NaN                            NaN
# 2746                        NaN                            NaN
#
#      incident_dateonly_created is_active calfire_incident notification_desired
# 0                   2017-10-31         N            False                False
# 1                   2009-05-24         N             True                False
# 2                   2013-02-24         N             True                False
# 3                   2013-04-20         N            False                False
# 4                   2013-04-30         N             True                False
# ...                        ...       ...              ...                  ...
# 2742                2024-10-06         N             True                False
# 2743                2024-10-06         Y             True                False
# 2744                2024-10-07         Y             True                False
# 2745                2024-10-08         Y             True                False
# 2746                2024-10-08         Y             True                False
#
# [2747 rows x 23 columns]

# %%
#1.How many variables and observations?
DF_raw.shape
# Out:
# (2747, 23)

# %% [markdown]
# This code show that there is 2747 rows (observations) and 23 columns (variables).

# %%
#2.How many different incident types are there?
columns=['incident_name' ,'incident_type']
DF_raw[columns].groupby('incident_type').sum()
# Out:
#                                                    incident_name
# incident_type
# Fire           Refuge FireLine FireWestwood FireLuis FireCoyo...
# Flood                                             Honey Flooding
# Wildfire       Pala FireSand FireWragg FireButte FireAtlas Fi...

# %% [markdown]
# In this code is tried to different incident types.

# %%
#3. Make a histogram of the acres burned and color the bars by whether or not the incident was a calfire incident.
#You will probably need to make a mask to remove very small and very large fires.
#How many fires burned more than 100,000 acres? What is the largest fire in the data?
fig = px.histogram(
                  DF_raw,
                  y='incident_acres_burned',
                  x='calfire_incident',
                  nbins= 6, color_discrete_sequence=['pink'])
fig.update_layout(bargap=0.1,
                  title='Histogram of acres burned.')
mask = (DF_raw['calfire_incident'])
fig.show()

# %% [markdown]
# In this histogram I tried to show the fires, in the first like DF_raw, we select all data and then in the x and y axis we put the information we are looking for.

# %%
#4.graph that answers the question: Are fires getting bigger or more frequent over time? 
#ou get complete creative control on how to answer this question!
fig = px.histogram(DF_raw,
                   x='incident_date_last_update',
                   labels={'incident_acres_burned':'incident_acres_burned'},
                   opacity=0.9,
                   color_discrete_sequence=['pink'])
fig.update_layout(bargap=0.3, title=
            'Are fires getting bigger or more frequent over time?',
            title_x=0.5)
fig.show()

# %% [markdown]
# This graph shows the fires through the years, in the first lines i select the information of the dates and then the other line shows the fires.

# %% [markdown]
# ## Try reading in some data from Wikipedia - html
#
# Here we will explore academy award winning films. Go to the [Wiki for the List of Academy Award Winning Films](https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films). Look at what type of data is there. How many tables? Any weird looking data?
#
# Now read the html data into Python and show the data in DF[0]

# %%
# Your code here
DF[0]
# Out:
#                                                    Film  Year Awards  \
# 0                                           Oppenheimer  2023      7
# 1                                           Poor Things  2023      4
# 2                                  The Zone of Interest  2023      2
# 3                                      American Fiction  2023      1
# 4                                     Anatomy of a Fall  2023      1
# ...                                                 ...   ...    ...
# 1368                            The Yankee Doodle Mouse  1943      1
# 1369                                       The Yearling  1946      2
# 1370  Yesterday, Today and Tomorrow (Ieri, oggi, dom...  1964      1
# 1371                         You Can't Take It with You  1938      2
# 1372                    Zorba the Greek (Alexis Zorbas)  1964      3
#
#      Nominations
# 0             13
# 1             11
# 2              5
# 3              5
# 4              5
# ...          ...
# 1368           1
# 1369           7
# 1370           1
# 1371           7
# 1372           7
#
# [1373 rows x 4 columns]

# %%
# Here is some helper code
# This is code that will read in the data and then fix the Year column
my_website = "https://en.wikipedia.org/wiki/List_of_Academy_Award%E2%80%93winning_films"
DF = pd.read_html(my_website)
DF_raw = DF[0]
DF_raw['Year'] = DF_raw['Year'].apply(lambda x: int(x.split('/')[0]))
DF_raw['Year'].value_counts().reset_index().rename(columns={"index": "value", 0: "count"})
# Out:
#     Year  count
# 0   1945     21
# 1   1949     20
# 2   1942     20
# 3   1950     19
# 4   1948     19
# ..   ...    ...
# 91  1931     10
# 92  1932      9
# 93  1928      7
# 94  1929      6
# 95  1930      6
#
# [96 rows x 2 columns]

# %% [markdown]
# **Q4** Following along with the lecture notes or video, fix the data in the 'Awards' column.

# %%
# Your code here
award_data = DF_raw['Awards'].value_counts()
DF_award = award_data.reset_index().rename(columns={"index": "value", 0: "count"})
DF_award
# Out:
#       Awards  count
# 0          1    979
# 1          2    156
# 2          3     77
# 3          4     47
# 4      0 (1)     32
# 5          5     25
# 6          7     12
# 7          6     12
# 8      1 (1)      8
# 9          8      7
# 10        11      3
# 11         9      3
# 12     0 (2)      3
# 13  0 (1)[1]      1
# 14     3 (1)      1
# 15     4 (1)      1
# 16     6 (1)      1
# 17     5 (1)      1
# 18     7 (1)      1
# 19     8 (2)      1
# 20     2 (1)      1
# 21        10      1

# %% [markdown]
# **Q5** Now try to fix the data in the "Nominations" column - see if you can do it without looking at the answer.

# %%
# Your code here
nom_data = DF_raw['Nominations'].value_counts()
DF_nom = nom_data.reset_index().rename(columns={"index": "value", 0: "count"})
show(DF_nom)
# Out:
# <table id="itables_9d73c27d_d57d_4e0f_9ed0_ce72e44017fd" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#
#       <th>Nominations</th>
#       <th>count</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.2.1 from the internet...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <link href="https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.css" rel="stylesheet">
# <script type="module">
#     import {DataTable, jQuery as $} from 'https://www.unpkg.com/dt_for_itables@2.0.13/dt_bundle.js';
#
#     document.querySelectorAll("#itables_9d73c27d_d57d_4e0f_9ed0_ce72e44017fd:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["1", 550], ["2", 141], ["4", 113], ["5", 104], ["3", 103], ["6", 78], ["7", 75], ["8", 61], ["10", 39], ["9", 31], ["11", 24], ["12", 17], ["0", 14], ["13", 11], ["14", 3], ["1[2]", 1], ["3[3]", 1], ["10[4]", 1], ["1[5]", 1], ["1[6]", 1], ["4[7]", 1], ["6[8]", 1], ["4[9]", 1], ["6[10]", 1]];
#
#         // Define the dt_args
#         let dt_args = {"layout": {"topStart": "pageLength", "topEnd": "search", "bottomStart": "info", "bottomEnd": "paging"}, "order": [], "warn_on_selected_rows_not_rendered": true};
#         dt_args["data"] = data;
#
#
#         new DataTable(table, dt_args);
#     });
# </script>

# %% [markdown]
# ## Problem 1
#
# Your homework today will be to see if you can find some data of your own. This can be the first steps you take toward your final project.
#
# You should:
#
# * Find some data online
# * Read that data into Python using the Pandas commands we learned
# * **Look at the DataFrame - number of variables, number of observations, AND the dtypes. Comment on what you see.**
#
# * Try to do summary statistics (.describe()). Does it work like expected?
# * Attempt to fix any data, or explain why the data does not need to be fixed.
# * Make some sort of graph using columns in your data.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.io as pio
pio.renderers.defaule = 'colab'

from itables import show

# %%
DF_raw = pd.read_csv('Adoptable_pets.csv')
DF_raw
# Out:
#    Animal ID Intake Type     In Date      Pet name Animal Type  \
# 0    A518499   OWNER SUR  04/27/2024            DJ       OTHER
# 1    A523470   OWNER SUR  09/15/2024        NORMAN       OTHER
# 2    A523467   OWNER SUR  09/15/2024        RODNEY       OTHER
# 3    A523469   OWNER SUR  09/15/2024        DEXTER       OTHER
# 4    A476852   OWNER SUR  09/09/2024           TAZ         DOG
# 5    A478355   OWNER SUR  09/12/2024         T-REX         DOG
# 6    A425626   OWNER SUR  09/17/2024          TOBY         DOG
# 7    A522396   OWNER SUR  08/20/2024     *CASHMERE         DOG
# 8    A524085   OWNER SUR  09/29/2024     *SSSSLEET       OTHER
# 9    A524084   OWNER SUR  09/29/2024     *SSSSNOWY       OTHER
# 10   A517854   OWNER SUR  08/26/2024         MUSSA         DOG
# 11   A524086   OWNER SUR  09/29/2024     *MISSSSTY       OTHER
# 12   A522314      FOSTER  09/30/2024       *VESTER         DOG
# 13   A517709      RETURN  09/19/2024          REMY         DOG
# 14   A523472   OWNER SUR  09/15/2024           RUE       OTHER
# 15   A523471   OWNER SUR  09/15/2024        SUMMER       OTHER
# 16   A523315   OWNER SUR  09/11/2024        HUNCHO         DOG
# 17   A523475   OWNER SUR  09/15/2024          RUBY       OTHER
# 18   A523468   OWNER SUR  09/15/2024         SONIC       OTHER
# 19   A523058   OWNER SUR  09/05/2024          PHIL         CAT
# 20   A512748   OWNER SUR  07/08/2024         MISSY         DOG
# 21   A523106      FOSTER  10/02/2024      *SHIRLEY         DOG
# 22   A523105      FOSTER  10/02/2024      *LAVERNE         DOG
# 23   A510411   OWNER SUR  10/01/2024       GEORGIA         CAT
# 24   A510410   OWNER SUR  10/01/2024       VINCENT         CAT
# 25   A508644   OWNER SUR  06/30/2024        JULIET         DOG
# 26   A524255    EUTH REQ  10/03/2024          LUNA       OTHER
# 27   A516562   OWNER SUR  08/09/2024         ROCKY         DOG
# 28   A524295   OWNER SUR  10/05/2024       *CONNIE       OTHER
# 29   A523169   OWNER SUR  09/08/2024  *JERSEY MIKE         DOG
# 30   A524094   OWNER SUR  09/29/2024   *ZOMBIE CAT         CAT
# 31   A524093   OWNER SUR  09/29/2024     *SKELECAT         CAT
# 32   A524311   OWNER SUR  10/05/2024           MAX       OTHER
# 33   A524294   OWNER SUR  10/05/2024      *CEE CEE       OTHER
# 34   A524170   OWNER SUR  10/01/2024       CUPCAKE       OTHER
# 35   A520093      RETURN  10/06/2024         *IGGY         DOG
# 36   A523228  CONFISCATE  09/09/2024      *ROMAN 1        BIRD
# 37   A522194   OWNER SUR  08/15/2024        HATCHI         DOG
# 38   A524293   OWNER SUR  10/05/2024        *CAREN       OTHER
# 39   A488833   OWNER SUR  09/01/2024          KANE         DOG
# 40   A433059   OWNER SUR  09/12/2024   MR. PICKLES         DOG
# 41   A523872    BOARDING  09/23/2024         *DOVE         CAT
# 42   A520705       STRAY  07/07/2024       *BULLET         DOG
# 43   A523945       STRAY  09/25/2024       *GRUMPY       OTHER
# 44   A523946       STRAY  09/25/2024        *DOPEY       OTHER
# 45   A523944       STRAY  09/25/2024          *DOC       OTHER
# 46   A524077       STRAY  09/28/2024       *JULIUS       OTHER
# 47   A523915       STRAY  09/24/2024          *JOE         DOG
# 48   A521124       STRAY  07/18/2024       *CHANEL         DOG
# 49   A523515       STRAY  09/16/2024     *TIRAMISU         DOG
#
#              Pet Age Pet Size              Color  \
# 0             NO AGE    SMALL              GREEN
# 1            3 YEARS      MED           TRICOLOR
# 2            3 YEARS      MED      BROWN / WHITE
# 3            3 YEARS      MED     AGOUTI / WHITE
# 4            6 YEARS      MED              BLACK
# 5            8 YEARS    LARGE      BROWN / WHITE
# 6            8 YEARS    LARGE        TAN / WHITE
# 7            3 YEARS      MED        TAN / WHITE
# 8             NO AGE      MED      BROWN / BLACK
# 9             NO AGE      MED      BROWN / BLACK
# 10           4 YEARS      MED              SABLE
# 11            NO AGE      MED      BROWN / BLACK
# 12           2 YEARS      MED      BROWN / WHITE
# 13   1 YEAR 6 MONTHS    LARGE        TAN / WHITE
# 14    1 YEAR 1 MONTH      MED             SILVER
# 15    1 YEAR 1 MONTH      MED              BROWN
# 16   1 YEAR 6 MONTHS      MED        TAN / WHITE
# 17    1 YEAR 1 MONTH      MED      WHITE / BROWN
# 18    1 YEAR 1 MONTH      MED      BROWN / WHITE
# 19          12 YEARS    X-LRG               GRAY
# 20  1 YEAR 11 MONTHS    LARGE    BRINDLE / WHITE
# 21    1 YEAR 1 MONTH      MED      BROWN / WHITE
# 22    1 YEAR 1 MONTH      MED      BROWN / WHITE
# 23          14 YEARS    X-LRG  BRN TABBY / WHITE
# 24          14 YEARS    X-LRG      BLACK / WHITE
# 25           2 YEARS      MED      BROWN / WHITE
# 26           3 YEARS      MED              BROWN
# 27           2 YEARS      MED               GRAY
# 28           3 YEARS    SMALL              BROWN
# 29          9 MONTHS      MED              BROWN
# 30           2 YEARS      MED      TORTIE / GRAY
# 31           3 YEARS      MED             ORANGE
# 32           5 YEARS    SMALL             BLONDE
# 33           6 YEARS    SMALL              BROWN
# 34           5 YEARS    LARGE              BLACK
# 35   1 YEAR 2 MONTHS      MED  CHOCOLATE / WHITE
# 36            NO AGE      MED      BLACK / WHITE
# 37         10 MONTHS      MED      BROWN / WHITE
# 38           6 YEARS    SMALL              BROWN
# 39           3 YEARS    LARGE    BRINDLE / WHITE
# 40           7 YEARS      MED      BROWN / WHITE
# 41           2 YEARS      MED             TORTIE
# 42   1 YEAR 3 MONTHS    LARGE       GRAY / WHITE
# 43            NO AGE    SMALL              WHITE
# 44            NO AGE    SMALL              WHITE
# 45            NO AGE    SMALL              WHITE
# 46            1 YEAR    SMALL       WHITE / GRAY
# 47    1 YEAR 1 MONTH      MED    BRINDLE / WHITE
# 48           3 YEARS    LARGE            BRINDLE
# 49           4 YEARS      MED      BROWN / WHITE
#
#                               Breed Sex  \
# 0          TURTLE / REDEARED SLIDER   F
# 1                        GUINEA PIG   M
# 2                        GUINEA PIG   M
# 3                        GUINEA PIG   M
# 4                   AM PIT BULL TER   N
# 5   AM PIT BULL TER / LABRADOR RETR   N
# 6             AM PIT BULL TER / MIX   N
# 7                       FEIST / MIX   N
# 8                             SNAKE   U
# 9                             SNAKE   U
# 10                    BELG MALINOIS   S
# 11                            SNAKE   U
# 12                      AKITA / MIX   N
# 13           MASTIFF / AMER BULLDOG   N
# 14                              RAT   F
# 15                              RAT   F
# 16                  AM PIT BULL TER   N
# 17                              RAT   F
# 18                       GUINEA PIG   M
# 19                      DOMESTIC SH   S
# 20                  AM PIT BULL TER   S
# 21                    ALASKAN HUSKY   S
# 22                    ALASKAN HUSKY   S
# 23                      DOMESTIC SH   S
# 24                      DOMESTIC SH   N
# 25                  AM PIT BULL TER   S
# 26                        RABBIT SH   F
# 27                  AM PIT BULL TER   N
# 28                           TURTLE   U
# 29                  AM PIT BULL TER   N
# 30                      DOMESTIC SH   S
# 31                      DOMESTIC SH   S
# 32                        RABBIT SH   M
# 33                           TURTLE   U
# 34         TURTLE / REDEARED SLIDER   F
# 35                  AM PIT BULL TER   S
# 36                           TURKEY   U
# 37    AUST SHEPHERD / LABRADOR RETR   N
# 38                           TURTLE   U
# 39                      BOXER / MIX   N
# 40                   SIBERIAN HUSKY   N
# 41                      DOMESTIC SH   S
# 42                      AKITA / MIX   N
# 43                          HAMSTER   M
# 44                          HAMSTER   M
# 45                          HAMSTER   M
# 46                        RABBIT SH   M
# 47                  AM PIT BULL TER   N
# 48                  AM PIT BULL TER   S
# 49                  AM PIT BULL TER   N
#
#                                             URL Link   \
# 0   http://www.petharbor.com/get_image.asp?res=DET...
# 1   http://www.petharbor.com/get_image.asp?res=DET...
# 2   http://www.petharbor.com/get_image.asp?res=DET...
# 3   http://www.petharbor.com/get_image.asp?res=DET...
# 4   http://www.petharbor.com/get_image.asp?res=DET...
# 5   http://www.petharbor.com/get_image.asp?res=DET...
# 6   http://www.petharbor.com/get_image.asp?res=DET...
# 7   http://www.petharbor.com/get_image.asp?res=DET...
# 8   http://www.petharbor.com/get_image.asp?res=DET...
# 9   http://www.petharbor.com/get_image.asp?res=DET...
# 10  http://www.petharbor.com/get_image.asp?res=DET...
# 11  http://www.petharbor.com/get_image.asp?res=DET...
# 12  http://www.petharbor.com/get_image.asp?res=DET...
# 13  http://www.petharbor.com/get_image.asp?res=DET...
# 14  http://www.petharbor.com/get_image.asp?res=DET...
# 15  http://www.petharbor.com/get_image.asp?res=DET...
# 16  http://www.petharbor.com/get_image.asp?res=DET...
# 17  http://www.petharbor.com/get_image.asp?res=DET...
# 18  http://www.petharbor.com/get_image.asp?res=DET...
# 19  http://www.petharbor.com/get_image.asp?res=DET...
# 20  http://www.petharbor.com/get_image.asp?res=DET...
# 21  http://www.petharbor.com/get_image.asp?res=DET...
# 22  http://www.petharbor.com/get_image.asp?res=DET...
# 23  http://www.petharbor.com/get_image.asp?res=DET...
# 24  http://www.petharbor.com/get_image.asp?res=DET...
# 25  http://www.petharbor.com/get_image.asp?res=DET...
# 26  http://www.petharbor.com/get_image.asp?res=DET...
# 27  http://www.petharbor.com/get_image.asp?res=DET...
# 28  http://www.petharbor.com/get_image.asp?res=DET...
# 29  http://www.petharbor.com/get_image.asp?res=DET...
# 30  http://www.petharbor.com/get_image.asp?res=DET...
# 31  http://www.petharbor.com/get_image.asp?res=DET...
# 32  http://www.petharbor.com/get_image.asp?res=DET...
# 33  http://www.petharbor.com/get_image.asp?res=DET...
# 34  http://www.petharbor.com/get_image.asp?res=DET...
# 35  http://www.petharbor.com/get_image.asp?res=DET...
# 36  http://www.petharbor.com/get_image.asp?res=DET...
# 37  http://www.petharbor.com/get_image.asp?res=DET...
# 38  http://www.petharbor.com/get_image.asp?res=DET...
# 39  http://www.petharbor.com/get_image.asp?res=DET...
# 40  http://www.petharbor.com/get_image.asp?res=DET...
# 41  http://www.petharbor.com/get_image.asp?res=DET...
# 42  http://www.petharbor.com/get_image.asp?res=DET...
# 43  http://www.petharbor.com/get_image.asp?res=DET...
# 44  http://www.petharbor.com/get_image.asp?res=DET...
# 45  http://www.petharbor.com/get_image.asp?res=DET...
# 46  http://www.petharbor.com/get_image.asp?res=DET...
# 47  http://www.petharbor.com/get_image.asp?res=DET...
# 48  http://www.petharbor.com/get_image.asp?res=DET...
# 49  http://www.petharbor.com/get_image.asp?res=DET...
#
#                                             Crossing
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42        18400 GUILDBERRY DR, GAITHERSBURG MD 20879
# 43            7700 DEMOCRACY BLVD, BETHESDA MD 20817
# 44            7700 DEMOCRACY BLVD, BETHESDA MD 20817
# 45            7700 DEMOCRACY BLVD, BETHESDA MD 20817
# 46           14700 CLAUDE LN, SILVER SPRING MD 20905
# 47  400 BLOCK OF WEST SIDE DR, GAITHERSBURG MD 20878
# 48          8000 GEORGIA AVE, SILVER SPRING MD 20910
# 49                   3200 SPARTAN RD, OLNEY MD 20832

# %%
DF_raw.shape
# Out:
# (50, 12)

# %%
DF_raw.dtypes
# Out:
# Animal ID      object
# Intake Type    object
# In Date        object
# Pet name       object
# Animal Type    object
# Pet Age        object
# Pet Size       object
# Color          object
# Breed          object
# Sex            object
# URL Link       object
# Crossing       object
# dtype: object

# %%
#Look at the DataFrame - number of variables, number of observations, AND the dtypes. Comment on what you see.

# %% [markdown]
# This graph has 50 rows (variables) and 12 columns (observations). I see the graph showing information about pets, like their names and basic description. On dtypes its only object.

# %%
#Try to do summary statistics (.describe()). Does it work like expected?
DF_raw.describe()
# Out:
#        Animal ID Intake Type     In Date Pet name Animal Type  Pet Age  \
# count         50          50          50       50          50       50
# unique        50           7          30       50           4       18
# top      A518499   OWNER SUR  09/15/2024       DJ         DOG  3 YEARS
# freq           1          34           7        1          22        9
#
#        Pet Size          Color            Breed Sex  \
# count        50             50               50  50
# unique        4             24               20   5
# top         MED  BROWN / WHITE  AM PIT BULL TER   N
# freq         30             10               10  16
#
#                                                 URL Link   \
# count                                                  50
# unique                                                 50
# top     http://www.petharbor.com/get_image.asp?res=DET...
# freq                                                    1
#
#                                       Crossing
# count                                        8
# unique                                       6
# top     7700 DEMOCRACY BLVD, BETHESDA MD 20817
# freq                                         3

# %% [markdown]
# Yes the code does work, it has the most basic information I think. It does do a summary so it's not as details, I think it's harder to read that way.

# %%
DF_raw.columns
my_columns=['Animal ID', 'Intake Type', 'In Date', 'Pet name', 'Animal Type',
       'Pet Age', 'Pet Size', 'Color', 'Breed', 'Sex',
       'Crossing']

# %%
#Attempt to fix any data, or explain why the data does not need to be fixed. 
DF_raw[my_columns]
# Out:
#    Animal ID Intake Type     In Date      Pet name Animal Type  \
# 0    A518499   OWNER SUR  04/27/2024            DJ       OTHER
# 1    A523470   OWNER SUR  09/15/2024        NORMAN       OTHER
# 2    A523467   OWNER SUR  09/15/2024        RODNEY       OTHER
# 3    A523469   OWNER SUR  09/15/2024        DEXTER       OTHER
# 4    A476852   OWNER SUR  09/09/2024           TAZ         DOG
# 5    A478355   OWNER SUR  09/12/2024         T-REX         DOG
# 6    A425626   OWNER SUR  09/17/2024          TOBY         DOG
# 7    A522396   OWNER SUR  08/20/2024     *CASHMERE         DOG
# 8    A524085   OWNER SUR  09/29/2024     *SSSSLEET       OTHER
# 9    A524084   OWNER SUR  09/29/2024     *SSSSNOWY       OTHER
# 10   A517854   OWNER SUR  08/26/2024         MUSSA         DOG
# 11   A524086   OWNER SUR  09/29/2024     *MISSSSTY       OTHER
# 12   A522314      FOSTER  09/30/2024       *VESTER         DOG
# 13   A517709      RETURN  09/19/2024          REMY         DOG
# 14   A523472   OWNER SUR  09/15/2024           RUE       OTHER
# 15   A523471   OWNER SUR  09/15/2024        SUMMER       OTHER
# 16   A523315   OWNER SUR  09/11/2024        HUNCHO         DOG
# 17   A523475   OWNER SUR  09/15/2024          RUBY       OTHER
# 18   A523468   OWNER SUR  09/15/2024         SONIC       OTHER
# 19   A523058   OWNER SUR  09/05/2024          PHIL         CAT
# 20   A512748   OWNER SUR  07/08/2024         MISSY         DOG
# 21   A523106      FOSTER  10/02/2024      *SHIRLEY         DOG
# 22   A523105      FOSTER  10/02/2024      *LAVERNE         DOG
# 23   A510411   OWNER SUR  10/01/2024       GEORGIA         CAT
# 24   A510410   OWNER SUR  10/01/2024       VINCENT         CAT
# 25   A508644   OWNER SUR  06/30/2024        JULIET         DOG
# 26   A524255    EUTH REQ  10/03/2024          LUNA       OTHER
# 27   A516562   OWNER SUR  08/09/2024         ROCKY         DOG
# 28   A524295   OWNER SUR  10/05/2024       *CONNIE       OTHER
# 29   A523169   OWNER SUR  09/08/2024  *JERSEY MIKE         DOG
# 30   A524094   OWNER SUR  09/29/2024   *ZOMBIE CAT         CAT
# 31   A524093   OWNER SUR  09/29/2024     *SKELECAT         CAT
# 32   A524311   OWNER SUR  10/05/2024           MAX       OTHER
# 33   A524294   OWNER SUR  10/05/2024      *CEE CEE       OTHER
# 34   A524170   OWNER SUR  10/01/2024       CUPCAKE       OTHER
# 35   A520093      RETURN  10/06/2024         *IGGY         DOG
# 36   A523228  CONFISCATE  09/09/2024      *ROMAN 1        BIRD
# 37   A522194   OWNER SUR  08/15/2024        HATCHI         DOG
# 38   A524293   OWNER SUR  10/05/2024        *CAREN       OTHER
# 39   A488833   OWNER SUR  09/01/2024          KANE         DOG
# 40   A433059   OWNER SUR  09/12/2024   MR. PICKLES         DOG
# 41   A523872    BOARDING  09/23/2024         *DOVE         CAT
# 42   A520705       STRAY  07/07/2024       *BULLET         DOG
# 43   A523945       STRAY  09/25/2024       *GRUMPY       OTHER
# 44   A523946       STRAY  09/25/2024        *DOPEY       OTHER
# 45   A523944       STRAY  09/25/2024          *DOC       OTHER
# 46   A524077       STRAY  09/28/2024       *JULIUS       OTHER
# 47   A523915       STRAY  09/24/2024          *JOE         DOG
# 48   A521124       STRAY  07/18/2024       *CHANEL         DOG
# 49   A523515       STRAY  09/16/2024     *TIRAMISU         DOG
#
#              Pet Age Pet Size              Color  \
# 0             NO AGE    SMALL              GREEN
# 1            3 YEARS      MED           TRICOLOR
# 2            3 YEARS      MED      BROWN / WHITE
# 3            3 YEARS      MED     AGOUTI / WHITE
# 4            6 YEARS      MED              BLACK
# 5            8 YEARS    LARGE      BROWN / WHITE
# 6            8 YEARS    LARGE        TAN / WHITE
# 7            3 YEARS      MED        TAN / WHITE
# 8             NO AGE      MED      BROWN / BLACK
# 9             NO AGE      MED      BROWN / BLACK
# 10           4 YEARS      MED              SABLE
# 11            NO AGE      MED      BROWN / BLACK
# 12           2 YEARS      MED      BROWN / WHITE
# 13   1 YEAR 6 MONTHS    LARGE        TAN / WHITE
# 14    1 YEAR 1 MONTH      MED             SILVER
# 15    1 YEAR 1 MONTH      MED              BROWN
# 16   1 YEAR 6 MONTHS      MED        TAN / WHITE
# 17    1 YEAR 1 MONTH      MED      WHITE / BROWN
# 18    1 YEAR 1 MONTH      MED      BROWN / WHITE
# 19          12 YEARS    X-LRG               GRAY
# 20  1 YEAR 11 MONTHS    LARGE    BRINDLE / WHITE
# 21    1 YEAR 1 MONTH      MED      BROWN / WHITE
# 22    1 YEAR 1 MONTH      MED      BROWN / WHITE
# 23          14 YEARS    X-LRG  BRN TABBY / WHITE
# 24          14 YEARS    X-LRG      BLACK / WHITE
# 25           2 YEARS      MED      BROWN / WHITE
# 26           3 YEARS      MED              BROWN
# 27           2 YEARS      MED               GRAY
# 28           3 YEARS    SMALL              BROWN
# 29          9 MONTHS      MED              BROWN
# 30           2 YEARS      MED      TORTIE / GRAY
# 31           3 YEARS      MED             ORANGE
# 32           5 YEARS    SMALL             BLONDE
# 33           6 YEARS    SMALL              BROWN
# 34           5 YEARS    LARGE              BLACK
# 35   1 YEAR 2 MONTHS      MED  CHOCOLATE / WHITE
# 36            NO AGE      MED      BLACK / WHITE
# 37         10 MONTHS      MED      BROWN / WHITE
# 38           6 YEARS    SMALL              BROWN
# 39           3 YEARS    LARGE    BRINDLE / WHITE
# 40           7 YEARS      MED      BROWN / WHITE
# 41           2 YEARS      MED             TORTIE
# 42   1 YEAR 3 MONTHS    LARGE       GRAY / WHITE
# 43            NO AGE    SMALL              WHITE
# 44            NO AGE    SMALL              WHITE
# 45            NO AGE    SMALL              WHITE
# 46            1 YEAR    SMALL       WHITE / GRAY
# 47    1 YEAR 1 MONTH      MED    BRINDLE / WHITE
# 48           3 YEARS    LARGE            BRINDLE
# 49           4 YEARS      MED      BROWN / WHITE
#
#                               Breed Sex  \
# 0          TURTLE / REDEARED SLIDER   F
# 1                        GUINEA PIG   M
# 2                        GUINEA PIG   M
# 3                        GUINEA PIG   M
# 4                   AM PIT BULL TER   N
# 5   AM PIT BULL TER / LABRADOR RETR   N
# 6             AM PIT BULL TER / MIX   N
# 7                       FEIST / MIX   N
# 8                             SNAKE   U
# 9                             SNAKE   U
# 10                    BELG MALINOIS   S
# 11                            SNAKE   U
# 12                      AKITA / MIX   N
# 13           MASTIFF / AMER BULLDOG   N
# 14                              RAT   F
# 15                              RAT   F
# 16                  AM PIT BULL TER   N
# 17                              RAT   F
# 18                       GUINEA PIG   M
# 19                      DOMESTIC SH   S
# 20                  AM PIT BULL TER   S
# 21                    ALASKAN HUSKY   S
# 22                    ALASKAN HUSKY   S
# 23                      DOMESTIC SH   S
# 24                      DOMESTIC SH   N
# 25                  AM PIT BULL TER   S
# 26                        RABBIT SH   F
# 27                  AM PIT BULL TER   N
# 28                           TURTLE   U
# 29                  AM PIT BULL TER   N
# 30                      DOMESTIC SH   S
# 31                      DOMESTIC SH   S
# 32                        RABBIT SH   M
# 33                           TURTLE   U
# 34         TURTLE / REDEARED SLIDER   F
# 35                  AM PIT BULL TER   S
# 36                           TURKEY   U
# 37    AUST SHEPHERD / LABRADOR RETR   N
# 38                           TURTLE   U
# 39                      BOXER / MIX   N
# 40                   SIBERIAN HUSKY   N
# 41                      DOMESTIC SH   S
# 42                      AKITA / MIX   N
# 43                          HAMSTER   M
# 44                          HAMSTER   M
# 45                          HAMSTER   M
# 46                        RABBIT SH   M
# 47                  AM PIT BULL TER   N
# 48                  AM PIT BULL TER   S
# 49                  AM PIT BULL TER   N
#
#                                             Crossing
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
# 10                                               NaN
# 11                                               NaN
# 12                                               NaN
# 13                                               NaN
# 14                                               NaN
# 15                                               NaN
# 16                                               NaN
# 17                                               NaN
# 18                                               NaN
# 19                                               NaN
# 20                                               NaN
# 21                                               NaN
# 22                                               NaN
# 23                                               NaN
# 24                                               NaN
# 25                                               NaN
# 26                                               NaN
# 27                                               NaN
# 28                                               NaN
# 29                                               NaN
# 30                                               NaN
# 31                                               NaN
# 32                                               NaN
# 33                                               NaN
# 34                                               NaN
# 35                                               NaN
# 36                                               NaN
# 37                                               NaN
# 38                                               NaN
# 39                                               NaN
# 40                                               NaN
# 41                                               NaN
# 42        18400 GUILDBERRY DR, GAITHERSBURG MD 20879
# 43            7700 DEMOCRACY BLVD, BETHESDA MD 20817
# 44            7700 DEMOCRACY BLVD, BETHESDA MD 20817
# 45            7700 DEMOCRACY BLVD, BETHESDA MD 20817
# 46           14700 CLAUDE LN, SILVER SPRING MD 20905
# 47  400 BLOCK OF WEST SIDE DR, GAITHERSBURG MD 20878
# 48          8000 GEORGIA AVE, SILVER SPRING MD 20910
# 49                   3200 SPARTAN RD, OLNEY MD 20832

# %% [markdown]
# In this code I fixed something by deleting the row of URL Link because the data of the link is simply not need it.

# %%
#Make some sort of graph using columns in your data.
px.bar(DF_raw,
             x = 'Pet Age',
            color='In Date')

# %%
This graph is showing different pet ages by date.
